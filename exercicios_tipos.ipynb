# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "050d54d9",
   "metadata": {},
   "source": [
    "### Exercicio 1: Identificación de Tipos\n",
    "\n",
    "Dada esta lista de valores, identifica e amosa o tipo de cada un:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2c67fa00",
   "metadata": {},
   "outputs": [],
   "source": [
    "valores = [\n",
    "    42,\n",
    "    3.1416,\n",
    "    \"Ola Python\",\n",
    "    True,\n",
    "    [1, 2, 3],\n",
    "    (\"a\", \"b\", \"c\"),\n",
    "    {\"nome\": \"Gerardo\", \"edad\": 45},\n",
    "    {1, 2, 3, 2, 1},\n",
    "    None\n",
    "]"

  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "781eeea2",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución\n"
    " 42,\n", -- int
    "    3.1416,\n", -- float
    "    \"Ola Python\",\n",  str
    "    True,\n", --bool
    "    [1, 2, 3],\n", --list
    "    (\"a\", \"b\", \"c\"),\n", --tupla
    "    {\"nome\": \"Gerardo\", \"edad\": 45},\n",--dict
    "    {1, 2, 3, 2, 1},\n", --set
    "    None\n",--Nonetype


 ]
  },
  {
   "cell_type": "markdown",
   "id": "58c1680f",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "75bee95d",
   "metadata": {},
   "source": [
    "### Exercicio 2: Conversións de Tipo\n",
    "\n",
    "A partires dos seguintes elementos:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2bf75333",
   "metadata": {},
   "outputs": [],
   "source": [
    "numero_str = \"1234\"\n",
    "numero_float = 45.67\n",
    "lista_numeros = [1, 2, 3, 4, 5]"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "4895e355",
   "metadata": {},
   "source": [
    "Realiza as seguintes conversións:\n",
    "\n",
    "1. numero_str a enteiro\n",

 "2. numero_float a enteiro (qué pasa coa parte decimal?)\n",

       "3. lista_numeros a tupla e a conxunto\n",

       "4. Crea un string que combine numero_str e numero_float"



   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "8e5ca92e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"

    numero_str = "1234"
numero_int = int(numero_str)
print(numero_int)

 "2. numero_float a enteiro (qué pasa coa parte decimal?)\n",
numero_float = 45.67
numero_entero= round(numero_float)
print(numero_entero)



 "3. lista_numeros a tupla e a conxunto\n",


lista_numeros = [1, 2, 3, 4, 5]
tupla_numeros = tuple(lista_numeros)
print(tupla_numeros)

   "4. Crea un string que combine numero_str e numero_float"


lista_numeros = [1, 2, 3, 4, 5]
conjunto_numeros = set(lista_numeros)
print(conjunto_numeros)



   ]
  },
  {
   "cell_type": "markdown",
   "id": "3e77164d",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "38d77269",
   "metadata": {},
   "source": [
    "### Exercicio 3: Cadeas\n",
    "\n",
    "A partires desta cadea:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "bde1b178",
   "metadata": {},
   "outputs": [],
   "source": [
    "texto = \"  Python é unha linguaxe de programación super famosa  \""
   ]
  },
  {
   "cell_type": "markdown",
   "id": "3fa7df02",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Elimina espazos ao comezo e ao final\n",
    "2. Convirte a maiúsculas\n",
    "3. Reempraza \"linguaxe\" por \"lang\"\n",
    "4. Divide o string en palabras\n",
    "5. Atopa a posición de \"programación\""
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "951dfb98",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"

texto= " Python é unha linguaxe de programación super famosa"

texto_sin_espacio= texto.lstrip()
print(texto_sin_espacio)

texto_sin_espacio= texto.rstrip()
print(texto_sin_espacio)

texto_mayuscula= texto.upper()
print(texto_mayuscula)

reemplaza= texto.replace('linguaxe','lang')
print(reemplaza)

dividir=texto.split()
print(dividir)

posición=texto.find('programación')
print(posición)

   ]
  },
  {
   "cell_type": "markdown",
   "id": "ba726ced",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "d8240bce",
   "metadata": {},
   "source": [
    "### Exercicio 4: Listas\n",
    "\n",
    "A partires da seguinte lista:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "3b86863a",
   "metadata": {},
   "outputs": [],
   "source": [
    "frutas = [\"mazá\", \"plátano\", \"laranxa\", \"uva\", \"mazá\"]"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "19ff6134",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Engade \"pera\" ao final\n",
    "2. Inserta \"kiwi\" na posición 2\n",
    "3. Elimina a primera \"mazá\"\n",
    "4. Ordena a lista alfabéticamente\n",
    "5. Crea unha nova lista coas frutas que teñen máis de 5 letras\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "1ce1a9d8",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"


       frutas = ["mazá", "plátano", "laranxa", "uva", "mazá"]

frutas.append("pera")
print(frutas)

frutas.insert(2, "kiwi")
print(frutas)

frutas.remove("mazá")
print(frutas)

frutas.sort()
print(frutas)

for fruta in frutas:
    if len(fruta) > 5:
        print(fruta)



   ]
  },
  {
   "cell_type": "markdown",
   "id": "208f524e",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "5db9b0a8",
   "metadata": {},
   "source": [
    "### Ejercicio 5: Tuplas\n",
    "\n",
    "Crea unha tupla coas coordenadas (x, y, z)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ec3b82e9",
   "metadata": {},
   "outputs": [],
   "source": [
    "coordenadas = (3, 7, 2)"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "f7e41c0e",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Accede a cada coordenada individualmente\n",
    "2. Intenta modificar unha coordenada (qué ocorre?)\n",
    "3. Convirte a tupla a lista\n",
    "4. Crea unha nova tupla concatenando (1, 2, 3)\n",
    "5. Desempaqueta a tupla en variables x, y, z"



   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ac8f5395",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"
coordenadas=(3,7,2)

x = coordenadas[0]
print(x)
y= coordenadas[1]
print(y)
z= coordenadas[2]
print(z)

#coordenadas[1]=(3)

#TypeError: 'tuple' object does not support item assignment --es inmutable

lista_coordenadas=list(coordenadas)
print(lista_coordenadas)

nueva_tupla=coordenadas + (1,2,3)
print(nueva_tupla)


x, y, z = coordenadas
print(x, y, z)



   ]
  },
  {
   "cell_type": "markdown",
   "id": "45af8b94",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "50ce0a87",
   "metadata": {},
   "source": [
    "### Exercicio 6: Diccionarios\n",
    "\n",
    "A partires do seguinte diccionario:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "739ae49d",
   "metadata": {},
   "outputs": [],
   "source": [
    "estudante = {\n",
    "    \"nome\": \"Carlos\",\n",
    "    \"idade\": 35,\n",
    "    \"modulos\": [\"Redes\", \"Sistemas\", \"Programación\"],\n",
    "    \"activo\": True\n",
    "}"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "b88fc35d",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Engade a chave \"promedio\" con valor 8.5\n",
    "2. Actualiza la idade a 40\n",
    "3. Engade \"Hardware\" á lista de módulos\n",
    "4. Amosa todas as chaves do diccionario\n",
    "5. Crea unha copia do diccionario e modifica a copia"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "db57e10e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"
import copy

estudante = {
    "nome": "Carlos",
    "idade": 35,
    "modulos": ["Redes", "Sistemas", "Programación"],
    "activo": True
}

estudante["promedio"]= 8.5

estudante["edad"]=40

estudante["modulos"].append("hardware")

print(estudante.keys())

copia_estudante=copy.deepcopy(estudante)
print(copia_estudante)




   ]
  },
  {
   "cell_type": "markdown",
   "id": "a989aea2",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "866a813b",
   "metadata": {},
   "source": [
    "### Exercicio 7: Lista de Diccionarios\n",
    "\n",
    "Crea unha lista de diccionarios con información de estudantes:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2aa87531",
   "metadata": {},
   "outputs": [],
   "source": [
    "estudantes = [\n",
    "    {\"nome\": \"Ana\", \"idade\": 20, \"nota\": 8.5},\n",
    "    {\"nome\": \"Carlos\", \"idade\": 22, \"nota\": 7.8},\n",
    "    {\"nome\": \"María\", \"idade\": 21, \"nota\": 9.2}\n",
    "]"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "0f59e2f2",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Engade un nopvo estudante.\n",
    "2. Atopa o estudiante con maior nota.\n",
    "3. Calcula o promedio de idades.\n",
    "4. Crea unha lista só cos nomes.\n",
    "5. Ordena os estudantes por nota (descendente)."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "88eaa151",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"

estudantes = [
    {"nome": "Ana", "idade": 20, "nota": 8.5},
    {"nome": "Carlos", "idade": 22, "nota": 7.8},
    {"nome": "María", "idade": 21, "nota": 9.2}
]

estudantes.append({"nome":"Deidre", "idade": 35, "nota": 8.5})

mas_nota= max(estudantes, key=lambda e: e["nota"])
print(mas_nota)

promedio_edad=sum(e["idade"] for e in estudantes) /len(estudantes)
print(promedio_edad)

nombres=[e["nome"] for e in estudantes]
print(nombres)

orden_descedente=sorted(estudantes, key=lambda e: e["nota"], reverse=True)
print(orden_descedente)


   ]
  },
  {
   "cell_type": "markdown",
   "id": "51cb45a9",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "f2d14ade",
   "metadata": {},
   "source": [
    "### Exercicio 8: Conxuntos\n",
    "\n",
    "A partir destes conxuntos:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5b10aa55",
   "metadata": {},
   "outputs": [],
   "source": [
    "conx_a = {1, 2, 3, 4, 5}\n",
    "conx_b = {4, 5, 6, 7, 8}"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "8f13ec59",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Unión de ambos conxuntos\n",
    "2. Intersección\n",
    "3. Diferencia (A - B)\n",
    "4. Diferencia simétrica\n",
    "5. Verifica si 3 está en A"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5b68ea82",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"
conx_a = {1, 2, 3, 4, 5}
conx_b = {4, 5, 6, 7, 8}

union = conx_a | conx_b
print("Unión:", union)

interseccion = conx_a & conx_b
print("Intersección:", interseccion)

diferencia = conx_a - conx_b
print("Diferencia A - B:", diferencia)

dif_simetrica = conx_a ^ conx_b
print("Diferencia simétrica:", dif_simetrica)

print("3 está en A?:", 3 in conx_a)
   ]
  },
  {
   "cell_type": "markdown",
   "id": "42892489",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "a2bd2734",
   "metadata": {},
   "source": [
    "### Exercicio 9: Programa Integrador\n",
    "\n",
    "Crea un programa que:\n",
    "\n",
    "1. Pida ao usuario o seu nome, idade e cidade de residencia\n",
    "2. Almacene esa información nun diccionario\n",
    "3. Convirta a idade a enteiro\n",
    "4. Cree unha lista de hobbies (pregunta por 3 polo menos)\n",
    "5. Amose toda a información formateada de xeito lexible"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "c8ddfeae",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"

nome = input("Introduce o teu nome: ")
idade = input("Introduce a túa idade: ")
cidade = input("Introduce a túa cidade de residencia: ")

# 2. Almacenar nun diccionario
usuario = {
    "nome": nome,
    "idade": idade,
    "cidade": cidade
}

# 3. Converter a idade a enteiro
usuario["idade"] = int(usuario["idade"])

# 4. Crear lista de hobbies
hobbies = []
print("Introduce polo menos 3 hobbies:")
for i in range(3):
    hobby = input(f"Hobby {i+1}: ")
    hobbies.append(hobby)
usuario["hobbies"] = hobbies

# 5. Amosar toda a información de xeito lexible
print("\n--- Información do usuario ---")
for clave, valor in usuario.items():
    print(f"{clave.capitalize()}: {valor}")


   ]
  },
  {
   "cell_type": "markdown",
   "id": "d56b6c45",
   "metadata": {},
   "source": [
    "---"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "322ae764",
   "metadata": {},
   "source": [
    "### Exercicio 10: Combinación de Tipos Complexos\n",
    "\n",
    "Temos un Sistema de biblioteca:"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "ef7dc484",
   "metadata": {},
   "outputs": [],
   "source": [
    "biblioteca = {\n",
    "    \"libros\": [\n",
    "        {\n",
    "            \"titulo\": \"Cien años de soledad\",\n",
    "            \"autor\": \"Gabriel García Márquez\", \n",
    "            \"ano\": 1967,\n",
    "            \"xeneros\": {\"Realismo mágico\", \"Novela\"},\n",
    "            \"disponible\": True\n",
    "        },\n",
    "        {\n",
    "            \"titulo\": \"1984\",\n",
    "            \"autor\": \"George Orwell\",\n",
    "            \"ano\": 1949,\n",
    "            \"xeneros\": {\"Ciencia ficción\", \"Distopía\"},\n",
    "            \"disponible\": False\n",
    "        }\n",
    "    ],\n",
    "    \"usuarios\": {\n",
    "        \"001\": {\"nome\": \"Ana\", \"libros_prestados\": [\"1984\"]},\n",
    "        \"002\": {\"nome\": \"Carlos\", \"libros_prestados\": []}\n",
    "    }\n",
    "}"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "5caadcb4",
   "metadata": {},
   "source": [
    "Realiza estas operacións:\n",
    "\n",
    "1. Engade un novo libro.\n",
    "2. Marca un libro como non dispoñible.\n",
    "3. Atopa todos os libros dun xénero.\n",
    "4. Libros dispoñibles por autor.\n",
    "5. Usuario con máis libros prestados."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "84f86b40",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Escribe aquí o código da túa solución"

       novo_libro = {
    "titulo": "El Principito",
    "autor": "Antoine de Saint-Exupéry",
    "ano": 1943,
    "xeneros": {"Fábula", "Infantil"},
    "disponible": True
}

biblioteca["libros"].append(novo_libro)

for libro in biblioteca["libros"]:
    if libro["titulo"] == "Cien años de soledad":
        libro["disponible"] = False

xenero_buscado = "Novela"
libros_do_xenero = [libro["titulo"]
for libro in biblioteca["libros"]
if xenero_buscado in libro["xeneros"]]
print(libros_do_xenero)


autor_buscado = "George Orwell"
libros_dispoñibles = [libro["titulo"] for libro in biblioteca["libros"]
if libro["autor"] == autor_buscado and libro["disponible"]]
print(libros_dispoñibles)


usuario_max = max(biblioteca["usuarios"].values(), key=lambda u: len(u["libros_prestados"]))
print(usuario_max["nome"], len(usuario_max["libros_prestados"]))

   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
